# %% [markdown]
# Dataset:
# Use the UCI Wine Quality dataset (white wine), provided as a cleaned course copy. Each row contains
# physicochemical measurements. The target is binary: quality ≤ 5 = lower quality (0); quality > 5 = higher quality
# (1).
#     • Use a 80-20 split (80 training, 20 test)
#     • Do not use the held-out test set for model selection.
#     • You may use NumPy, Pandas, Matplotlib, and scikit-learn, including its KNN implementation.

# %% [markdown]
# Part A — Understand the Problem and Data [15 points]
# A1. [4 points] State the prediction task. What are the inputs, target, and learning setting? Why is this classification?
#
#
# A2. [5 points] Report the number of examples, input features, class distribution, and ranges of at least four features.Identify one feature-scale difference that could matter for KNN.
#
#
# A3. [6 points] Explain why a held-out test set is needed and why repeatedly using it while choosing k weakens the
# evaluation.

# %% [markdown]
# Part B — Representation and Baseline Model [20 points]

# %% [markdown]
# B1. [6 points] Fit KNN with k=5, Euclidean distance, and uniform voting using original feature values. Use cross-validation on training data; report mean accuracy and F1.

# %% [markdown]
# B2. [6 points] Standardize features using training-data statistics only. Repeat B1 and report the same metrics.

# %% [markdown]
# B3. [5 points] Explain why standardization can change KNN predictions, referring explicitly to distance and feature
# scale.

# %% [markdown]
# B4. [3 points] Explain why fitting the scaler on the complete dataset would be data leakage.

# %%
Part C — Model Choice and Generalization [30 points]

# %% [markdown]
# C1. [10 points] Using standardized features, compare k ∈ {1, 5, 11, 21} with 5-fold cross-validation. Use F1 as the primary selection metric and present a concise table.

# %% [markdown]
# C2. [8 points] For two informative k values, compare Euclidean and Manhattan distance. Does the preferred distance change your conclusion? Support your answer with evidence.

# %% [markdown]
# C3. [8 points] Choose a final configuration. Explain the trade-off between very small and larger k in terms of sensitivity, decision boundaries, and generalization.

# %% [markdown]
# C4. [4 points] Before testing, predict in one sentence how the selected model will perform relative to its cross-validation estimate.
